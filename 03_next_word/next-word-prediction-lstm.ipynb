# %%
import random
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 


import torch 
import torch.nn as nn 
from torch.utils.data import DataLoader, Dataset

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/next-word-prediction/1661-0.txt

# %%
random.seed(42)
pytorch_seed = torch.manual_seed(seed=42)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
df = pd.read_csv(filepath_or_buffer="/kaggle/input/next-word-prediction/1661-0.txt",
                 sep="\t",names=["data"],header=None)
df
# Out:
#                                                    data
# 0     Project Gutenberg's The Adventures of Sherlock...
# 1     This eBook is for the use of anyone anywhere a...
# 2     almost no restrictions whatsoever.  You may co...
# 3     re-use it under the terms of the Project Guten...
# 4        with this eBook or online at www.gutenberg.net
# ...                                                 ...
# 9628                        facility: www.gutenberg.org
# 9629  This Web site includes information about Proje...
# 9630  including how to make donations to the Project...
# 9631  Archive Foundation, how to help produce our ne...
# 9632  subscribe to our email newsletter to hear abou...
#
# [9633 rows x 1 columns]

# %% [markdown]
# <br>
#
# # `#01: Data preprocessing`
#
# - Make token
# - Make vocabulary
#
# <br>

# %%
# get the token:
df["data"][0].split(" ")
# Out:
# ['Project',
#  "Gutenberg's",
#  'The',
#  'Adventures',
#  'of',
#  'Sherlock',
#  'Holmes,',
#  'by',
#  'Arthur',
#  'Conan',
#  'Doyle']

# %%
# tokenization:
token = [df["data"][i].split(" ") for i in range(0,len(df))]
token[:5]
# Out:
# [['Project',
#   "Gutenberg's",
#   'The',
#   'Adventures',
#   'of',
#   'Sherlock',
#   'Holmes,',
#   'by',
#   'Arthur',
#   'Conan',
#   'Doyle'],
#  ['This',
#   'eBook',
#   'is',
#   'for',
#   'the',
#   'use',
#   'of',
#   'anyone',
#   'anywhere',
#   'at',
#   'no',
#   'cost',
#   'and',
#   'with'],
#  ['almost',
#   'no',
#   'restrictions',
#   'whatsoever.',
#   '',
#   'You',
#   'may',
#   'copy',
#   'it,',
#   'give',
#   'it',
#   'away',
#   'or'],
#  ['re-use',
#   'it',
#   'under',
#   'the',
#   'terms',
#   'of',
#   'the',
#   'Project',
#   'Gutenberg',
#   'License',
#   'included'],
#  ['with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.net']]

# %%
final_token = []
for i in range(len(token)):
    list_token = token[i]
    for tok in list_token:
        final_token.append(tok.lower().strip())
        
total_token = len(final_token)
print(f"Total token no: {total_token}")
print("-------------------------------")
final_token[:20]
# Out:
# Total token no: 108061
# -------------------------------
# ['project',
#  "gutenberg's",
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes,',
#  'by',
#  'arthur',
#  'conan',
#  'doyle',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere']

# %%
# Remove the duplicated words from token:
from collections import Counter
counter = Counter(final_token)
counter
# Out:
# Counter({'project': 85,
#          "gutenberg's": 1,
#          'the': 5703,
#          'adventures': 9,
#          'of': 2758,
#          'sherlock': 101,
#          'holmes,': 127,
#          'by': 357,
#          'arthur': 14,
#          'conan': 4,
#          'doyle': 4,
#          'this': 467,
#          'ebook': 8,
#          'is': 1080,
#          'for': 727,
#          'use': 39,
#          'anyone': 27,
#          'anywhere': 3,
#          'at': 768,
#          'no': 299,
#          'cost': 5,
#          'and': 2882,
#          'with': 870,
#          'almost': 20,
#          'restrictions': 2,
#          'whatsoever.': 2,
#          '': 459,
#          'you': 1173,
#          'may': 205,
#          'copy': 10,
#          'it,': 93,
#          'give': 60,
#          'it': 1267,
#          'away': 84,
#          'or': 267,
#          're-use': 2,
#          'under': 46,
#          'terms': 23,
#          'gutenberg': 26,
#          'license': 11,
#          'included': 3,
#          'online': 4,
#          'www.gutenberg.net': 1,
#          'title:': 1,
#          'holmes': 200,
#          'author:': 1,
#          'release': 1,
#          'date:': 1,
#          'november': 1,
#          '29,': 1,
#          '2002': 1,
#          '[ebook': 1,
#          '#1661]': 1,
#          'last': 75,
#          'updated:': 1,
#          '20,': 1,
#          '2019': 1,
#          'language:': 1,
#          'english': 9,
#          'character': 9,
#          'set': 49,
#          'encoding:': 1,
#          'utf-8': 1,
#          '***': 4,
#          'start': 13,
#          'produced': 4,
#          'an': 335,
#          'anonymous': 2,
#          'volunteer': 3,
#          'jose': 2,
#          'menendez': 2,
#          'cover': 6,
#          'contents': 3,
#          'i.': 25,
#          'a': 2648,
#          'scandal': 9,
#          'in': 1760,
#          'bohemia': 5,
#          'ii.': 3,
#          'red-headed': 19,
#          'league': 9,
#          'iii.': 3,
#          'case': 74,
#          'identity': 3,
#          'iv.': 2,
#          'boscombe': 15,
#          'valley': 5,
#          'mystery': 13,
#          'v.': 2,
#          'five': 32,
#          'orange': 10,
#          'pips': 8,
#          'vi.': 2,
#          'man': 195,
#          'twisted': 9,
#          'lip': 7,
#          'vii.': 2,
#          'adventure': 14,
#          'blue': 22,
#          'carbuncle': 2,
#          'viii.': 2,
#          'speckled': 5,
#          'band': 6,
#          'ix.': 2,
#          'engineer’s': 2,
#          'thumb': 9,
#          'x.': 2,
#          'noble': 14,
#          'bachelor': 3,
#          'xi.': 2,
#          'beryl': 3,
#          'coronet': 17,
#          'xii.': 2,
#          'copper': 12,
#          'beeches': 6,
#          'to': 2720,
#          'she': 389,
#          'always': 55,
#          '_the_': 3,
#          'woman.': 8,
#          'i': 2533,
#          'have': 903,
#          'seldom': 6,
#          'heard': 103,
#          'him': 253,
#          'mention': 2,
#          'her': 377,
#          'any': 162,
#          'other': 142,
#          'name.': 3,
#          'his': 1146,
#          'eyes': 58,
#          'eclipses': 1,
#          'predominates': 1,
#          'whole': 43,
#          'sex.': 1,
#          'was': 1371,
#          'not': 609,
#          'that': 1605,
#          'he': 1278,
#          'felt': 30,
#          'emotion': 3,
#          'akin': 3,
#          'love': 16,
#          'irene': 13,
#          'adler.': 2,
#          'all': 339,
#          'emotions,': 1,
#          'one': 308,
#          'particularly,': 1,
#          'were': 337,
#          'abhorrent': 1,
#          'cold,': 4,
#          'precise': 3,
#          'but': 541,
#          'admirably': 3,
#          'balanced': 1,
#          'mind.': 5,
#          'was,': 13,
#          'take': 76,
#          'most': 89,
#          'perfect': 6,
#          'reasoning': 7,
#          'observing': 4,
#          'machine': 12,
#          'world': 6,
#          'has': 280,
#          'seen,': 3,
#          'as': 848,
#          'lover': 5,
#          'would': 317,
#          'placed': 18,
#          'himself': 61,
#          'false': 4,
#          'position.': 4,
#          'never': 95,
#          'spoke': 19,
#          'softer': 1,
#          'passions,': 1,
#          'save': 35,
#          'gibe': 1,
#          'sneer.': 2,
#          'they': 177,
#          'admirable': 3,
#          'things': 24,
#          'observer—excellent': 1,
#          'drawing': 5,
#          'veil': 4,
#          'from': 498,
#          'men’s': 2,
#          'motives': 3,
#          'actions.': 2,
#          'trained': 4,
#          'reasoner': 3,
#          'admit': 2,
#          'such': 114,
#          'intrusions': 1,
#          'into': 272,
#          'own': 94,
#          'delicate': 7,
#          'finely': 1,
#          'adjusted': 2,
#          'temperament': 1,
#          'introduce': 4,
#          'distracting': 1,
#          'factor': 3,
#          'which': 754,
#          'might': 123,
#          'throw': 10,
#          'doubt': 49,
#          'upon': 461,
#          'mental': 1,
#          'results.': 3,
#          'grit': 1,
#          'sensitive': 1,
#          'instrument,': 1,
#          'crack': 2,
#          'high-power': 1,
#          'lenses,': 1,
#          'be': 615,
#          'more': 152,
#          'disturbing': 1,
#          'than': 159,
#          'strong': 32,
#          'nature': 14,
#          'his.': 1,
#          'yet': 66,
#          'there': 396,
#          'woman': 35,
#          'him,': 64,
#          'late': 16,
#          'adler,': 5,
#          'dubious': 1,
#          'questionable': 2,
#          'memory.': 4,
#          'had': 813,
#          'seen': 62,
#          'little': 257,
#          'lately.': 4,
#          'my': 955,
#          'marriage': 16,
#          'drifted': 2,
#          'us': 126,
#          'each': 33,
#          'other.': 9,
#          'complete': 10,
#          'happiness,': 2,
#          'home-centred': 1,
#          'interests': 3,
#          'rise': 5,
#          'up': 250,
#          'around': 2,
#          'who': 261,
#          'first': 67,
#          'finds': 4,
#          'master': 8,
#          'establishment,': 1,
#          'sufficient': 5,
#          'absorb': 1,
#          'attention,': 4,
#          'while': 67,
#          'loathed': 1,
#          'every': 81,
#          'form': 8,
#          'society': 6,
#          'bohemian': 4,
#          'soul,': 1,
#          'remained': 16,
#          'our': 209,
#          'lodgings': 7,
#          'baker': 33,
#          'street,': 24,
#          'buried': 6,
#          'among': 35,
#          'old': 64,
#          'books,': 3,
#          'alternating': 1,
#          'week': 13,
#          'between': 58,
#          'cocaine': 3,
#          'ambition,': 1,
#          'drowsiness': 1,
#          'drug,': 4,
#          'fierce': 6,
#          'energy': 3,
#          'keen': 9,
#          'nature.': 4,
#          'still,': 11,
#          'ever,': 5,
#          'deeply': 11,
#          'attracted': 5,
#          'study': 8,
#          'crime,': 4,
#          'occupied': 1,
#          'immense': 10,
#          'faculties': 2,
#          'extraordinary': 18,
#          'powers': 5,
#          'observation': 4,
#          'following': 15,
#          'out': 275,
#          'those': 65,
#          'clues,': 1,
#          'clearing': 8,
#          'mysteries': 2,
#          'been': 385,
#          'abandoned': 3,
#          'hopeless': 2,
#          'official': 14,
#          'police.': 5,
#          'time': 102,
#          'some': 238,
#          'vague': 8,
#          'account': 18,
#          'doings:': 1,
#          'summons': 2,
#          'odessa': 1,
#          'trepoff': 1,
#          'murder,': 2,
#          'singular': 32,
#          'tragedy': 3,
#          'atkinson': 1,
#          'brothers': 1,
#          'trincomalee,': 1,
#          'finally': 14,
#          'mission': 6,
#          'accomplished': 1,
#          'so': 336,
#          'delicately': 1,
#          'successfully': 1,
#          'reigning': 3,
#          'family': 20,
#          'holland.': 1,
#          'beyond': 10,
#          'these': 75,
#          'signs': 13,
#          'activity,': 1,
#          'however,': 97,
#          'merely': 10,
#          'shared': 2,
#          'readers': 1,
#          'daily': 3,
#          'press,': 4,
#          'knew': 53,
#          'former': 2,
#          'friend': 49,
#          'companion.': 10,
#          'night—it': 2,
#          'on': 366,
#          'twentieth': 2,
#          'march,': 2,
#          '1888—i': 1,
#          'returning': 10,
#          'journey': 5,
#          'patient': 1,
#          '(for': 1,
#          'now': 115,
#          'returned': 29,
#          'civil': 3,
#          'practice),': 1,
#          'when': 295,
#          'way': 79,
#          'led': 25,
#          'me': 414,
#          'through': 86,
#          'street.': 26,
#          'passed': 38,
#          'well-remembered': 1,
#          'door,': 30,
#          'must': 169,
#          'associated': 11,
#          'mind': 46,
#          'wooing,': 1,
#          'dark': 27,
#          'incidents': 5,
#          'scarlet,': 3,
#          'seized': 10,
#          'desire': 6,
#          'see': 190,
#          'again,': 15,
#          'know': 137,
#          'how': 115,
#          'employing': 1,
#          'powers.': 1,
#          'rooms': 19,
#          'brilliantly': 2,
#          'lit,': 2,
#          'and,': 57,
#          'even': 71,
#          'looked': 51,
#          'up,': 34,
#          'saw': 84,
#          'tall,': 6,
#          'spare': 6,
#          'figure': 14,
#          'pass': 12,
#          'twice': 14,
#          'silhouette': 1,
#          'against': 52,
#          'blind.': 2,
#          'pacing': 3,
#          'room': 57,
#          'swiftly,': 3,
#          'eagerly,': 1,
#          'head': 44,
#          'sunk': 8,
#          'chest': 5,
#          'hands': 42,
#          'clasped': 1,
#          'behind': 43,
#          'him.': 82,
#          'me,': 83,
#          'mood': 2,
#          'habit,': 2,
#          'attitude': 1,
#          'manner': 18,
#          'told': 49,
#          'their': 96,
#          'story.': 7,
#          'work': 58,
#          'again.': 15,
#          'risen': 3,
#          'drug-created': 1,
#          'dreams': 2,
#          'hot': 8,
#          'scent': 2,
#          'new': 32,
#          'problem.': 5,
#          'rang': 4,
#          'bell': 6,
#          'shown': 19,
#          'chamber': 10,
#          'formerly': 2,
#          'part': 32,
#          'own.': 3,
#          'effusive.': 1,
#          'was;': 1,
#          'glad,': 2,
#          'think,': 31,
#          'me.': 74,
#          'hardly': 50,
#          'word': 30,
#          'spoken,': 2,
#          'kindly': 15,
#          'eye,': 1,
#          'waved': 4,
#          'armchair,': 3,
#          'threw': 29,
#          'across': 35,
#          'cigars,': 2,
#          'indicated': 3,
#          'spirit': 1,
#          'gasogene': 1,
#          'corner.': 2,
#          'then': 160,
#          'stood': 34,
#          'before': 140,
#          'fire': 16,
#          'over': 163,
#          'introspective': 2,
#          'fashion.': 3,
#          '“wedlock': 1,
#          'suits': 2,
#          'you,”': 17,
#          'remarked.': 15,
#          '“i': 349,
#          'watson,': 40,
#          'put': 67,
#          'seven': 24,
#          'half': 38,
#          'pounds': 3,
#          'since': 32,
#          'you.”': 32,
#          '“seven!”': 1,
#          'answered.': 19,
#          '“indeed,': 5,
#          'should': 209,
#          'thought': 64,
#          'more.': 13,
#          'just': 119,
#          'trifle': 2,
#          'more,': 7,
#          'fancy,': 4,
#          'watson.': 10,
#          'practice': 8,
#          'observe.': 3,
#          'did': 137,
#          'tell': 86,
#          'intended': 1,
#          'go': 80,
#          'harness.”': 1,
#          '“then,': 11,
#          'do': 235,
#          'know?”': 1,
#          'deduce': 12,
#          'it.': 110,
#          'getting': 8,
#          'yourself': 33,
#          'very': 376,
#          'wet': 4,
#          'lately,': 2,
#          'clumsy': 1,
#          'careless': 1,
#          'servant': 5,
#          'girl?”': 1,
#          '“my': 43,
#          'dear': 49,
#          'holmes,”': 11,
#          'said': 447,
#          'i,': 33,
#          '“this': 34,
#          'too': 54,
#          'much.': 5,
#          'certainly': 27,
#          'burned,': 1,
#          'lived': 8,
#          'few': 77,
#          'centuries': 1,
#          'ago.': 6,
#          'true': 19,
#          'country': 21,
#          'walk': 14,
#          'thursday': 2,
#          'came': 142,
#          'home': 34,
#          'dreadful': 16,
#          'mess,': 1,
#          'changed': 5,
#          'clothes': 12,
#          'can’t': 12,
#          'imagine': 15,
#          'mary': 15,
#          'jane,': 1,
#          'incorrigible,': 1,
#          'wife': 35,
#          'given': 30,
#          'notice,': 1,
#          'there,': 25,
#          'fail': 3,
#          'out.”': 5,
#          'chuckled': 6,
#          'rubbed': 3,
#          'long,': 13,
#          'nervous': 8,
#          'together.': 8,
#          '“it': 133,
#          'simplicity': 1,
#          'itself,”': 1,
#          'he;': 8,
#          'inside': 11,
#          'your': 379,
#          'left': 77,
#          'shoe,': 1,
#          'where': 108,
#          'firelight': 1,
#          'strikes': 3,
#          'leather': 4,
#          'scored': 2,
#          'six': 21,
#          'parallel': 3,
#          'cuts.': 1,
#          'obviously': 5,
#          'caused': 15,
#          'someone': 15,
#          'carelessly': 1,
#          'scraped': 1,
#          'round': 68,
#          'edges': 3,
#          'sole': 2,
#          'order': 18,
#          'remove': 6,
#          'crusted': 1,
#          'mud': 3,
#          'hence,': 1,
#          'see,': 19,
#          'double': 12,
#          'deduction': 4,
#          'vile': 3,
#          'weather,': 1,
#          'particularly': 5,
#          'malignant': 1,
#          'boot-slitting': 1,
#          'specimen': 2,
#          'london': 20,
#          'slavey.': 1,
#          'practice,': 2,
#          'if': 254,
#          'gentleman': 32,
#          'walks': 3,
#          'smelling': 1,
#          'iodoform,': 1,
#          'black': 47,
#          'mark': 6,
#          'nitrate': 1,
#          'silver': 1,
#          'right': 65,
#          'forefinger,': 2,
#          'bulge': 1,
#          'side': 52,
#          'top-hat': 3,
#          'show': 16,
#          'secreted': 1,
#          'stethoscope,': 1,
#          'dull,': 1,
#          'indeed,': 16,
#          'pronounce': 2,
#          'active': 4,
#          'member': 4,
#          'medical': 9,
#          'profession.”': 1,
#          'could': 284,
#          'help': 39,
#          'laughing': 4,
#          'ease': 1,
#          'explained': 8,
#          'process': 3,
#          'deduction.': 1,
#          '“when': 19,
#          'hear': 31,
#          'reasons,”': 1,
#          'remarked,': 17,
#          '“the': 79,
#          'thing': 32,
#          'appears': 15,
#          'ridiculously': 1,
#          'simple': 14,
#          'easily': 10,
#          'myself,': 6,
#          'though': 60,
#          'successive': 3,
#          'instance': 4,
#          'am': 181,
#          'baffled': 3,
#          'until': 74,
#          'explain': 14,
#          'process.': 2,
#          'believe': 27,
#          'are': 322,
#          'good': 88,
#          'yours.”': 2,
#          '“quite': 14,
#          'so,”': 6,
#          'answered,': 11,
#          'lighting': 2,
#          'cigarette,': 1,
#          'throwing': 12,
#          'down': 205,
#          'armchair.': 2,
#          '“you': 120,
#          'distinction': 1,
#          'clear.': 5,
#          'example,': 5,
#          'frequently': 9,
#          'steps': 19,
#          'lead': 9,
#          'hall': 14,
#          'room.”': 7,
#          '“frequently.”': 1,
#          '“how': 21,
#          'often?”': 1,
#          '“well,': 67,
#          'hundreds': 3,
#          'times.”': 1,
#          '“then': 39,
#          'many': 39,
#          'there?”': 4,
#          'many?': 1,
#          'don’t': 27,
#          'know.”': 6,
#          'so!': 4,
#          'observed.': 5,
#          'seen.': 5,
#          'point.': 9,
#          'now,': 64,
#          'seventeen': 1,
#          'steps,': 3,
#          'because': 15,
#          'both': 45,
#          'way,': 17,
#          'interested': 9,
#          'problems,': 2,
#          'enough': 41,
#          'chronicle': 2,
#          'two': 135,
#          'trifling': 4,
#          'experiences,': 1,
#          'this.”': 3,
#          'sheet': 11,
#          'thick,': 3,
#          'pink-tinted': 1,
#          'notepaper': 1,
#          'lying': 14,
#          'open': 37,
#          'table.': 14,
#          'post,”': 1,
#          'he.': 61,
#          '“read': 1,
#          'aloud.”': 1,
#          'note': 18,
#          'undated,': 1,
#          'without': 80,
#          'either': 32,
#          'signature': 4,
#          'address.': 7,
#          '“there': 34,
#          'will': 253,
#          'call': 39,
#          'to-night,': 5,
#          'quarter': 6,
#          'eight': 12,
#          'o’clock,”': 1,
#          'said,': 21,
#          '“a': 24,
#          'desires': 2,
#          'consult': 7,
#          'matter': 75,
#          'deepest': 5,
#          'moment.': 4,
#          'recent': 5,
#          'services': 1,
#          'royal': 4,
#          'houses': 6,
#          'europe': 3,
#          'safely': 4,
#          'trusted': 2,
#          'matters': 13,
#          'importance': 8,
#          'can': 168,
#          'exaggerated.': 1,
#          'we': 502,
#          'quarters': 4,
#          'received.': 1,
#          'hour,': 2,
#          'amiss': 2,
#          'visitor': 14,
#          'wear': 6,
#          'mask.”': 1,
#          'indeed': 20,
#          'mystery,”': 2,
#          '“what': 51,
#          'means?”': 1,
#          'data': 3,
#          'yet.': 5,
#          'capital': 4,
#          'mistake': 4,
#          'theorise': 1,
#          'data.': 4,
#          'insensibly': 1,
#          'begins': 1,
#          'twist': 4,
#          'facts': 25,
#          'suit': 9,
#          'theories,': 1,
#          'instead': 8,
#          'theories': 3,
#          'facts.': 4,
#          'itself.': 2,
#          'what': 312,
#          'it?”': 24,
#          'carefully': 9,
#          'examined': 12,
#          'writing,': 3,
#          'paper': 26,
#          'written.': 1,
#          'wrote': 14,
#          'presumably': 2,
#          'well': 48,
#          'do,”': 3,
#          'endeavouring': 6,
#          'imitate': 1,
#          'companion’s': 4,
#          'processes.': 1,
#          '“such': 2,
#          'bought': 4,
#          'crown': 4,
#          'packet.': 1,
#          'peculiarly': 1,
#          'stiff.”': 1,
#          '“peculiar—that': 1,
#          'word,”': 1,
#          'holmes.': 78,
#          'all.': 19,
#          'hold': 8,
#          'light.”': 1,
#          'so,': 26,
#          'large': 40,
#          '“e”': 1,
#          'small': 75,
#          '“g,”': 1,
#          '“p,”': 1,
#          '“g”': 1,
#          '“t”': 1,
#          'woven': 2,
#          'texture': 1,
#          'paper.': 3,
#          'make': 76,
#          'that?”': 10,
#          'asked': 45,
#          'name': 43,
#          'maker,': 1,
#          'doubt;': 1,
#          'monogram,': 1,
#          'rather.”': 1,
#          '“not': 18,
#          '‘g’': 1,
#          '‘t’': 1,
#          'stands': 6,
#          '‘gesellschaft,’': 1,
#          'german': 10,
#          '‘company.’': 1,
#          'customary': 1,
#          'contraction': 2,
#          'like': 90,
#          '‘co.’': 1,
#          '‘p,’': 1,
#          'course,': 26,
#          '‘papier.’': 1,
#          '‘eg.’': 1,
#          'let': 63,
#          'glance': 15,
#          'continental': 1,
#          'gazetteer.”': 1,
#          'took': 84,
#          'heavy': 27,
#          'brown': 13,
#          'volume': 4,
#          'shelves.': 1,
#          '“eglow,': 1,
#          'eglonitz—here': 1,
#          'are,': 18,
#          'egria.': 1,
#          'german-speaking': 1,
#          'country—in': 1,
#          'bohemia,': 4,
#          'far': 53,
#          'carlsbad.': 1,
#          '‘remarkable': 1,
#          'being': 45,
#          'scene': 12,
#          'death': 12,
#          'wallenstein,': 1,
#          'its': 91,
#          'numerous': 2,
#          'glass-factories': 1,
#          'paper-mills.’': 1,
#          'ha,': 3,
#          'boy,': 6,
#          'sparkled,': 1,
#          'sent': 20,
#          'great': 58,
#          'triumphant': 1,
#          'cloud': 4,
#          'cigarette.': 1,
#          'made': 102,
#          'bohemia,”': 1,
#          'said.': 15,
#          '“precisely.': 4,
#          'german.': 1,
#          'peculiar': 19,
#          'construction': 1,
#          'sentence—‘this': 1,
#          'received.’': 1,
#          'frenchman': 1,
#          'russian': 1,
#          'written': 21,
#          'that.': 18,
#          'uncourteous': 1,
#          'verbs.': 1,
#          'only': 156,
#          'remains,': 2,
#          'therefore,': 11,
#          'discover': 4,
#          'wanted': 11,
#          'writes': 1,
#          'prefers': 1,
#          'wearing': 3,
#          'mask': 2,
#          'showing': 6,
#          'face.': 22,
#          'here': 72,
#          'comes,': 1,
#          'mistaken,': 3,
#          'resolve': 2,
#          'doubts.”': 2,
#          'sharp': 14,
#          'sound': 22,
#          'horses’': 2,
#          'hoofs': 1,
#          'grating': 1,
#          'wheels': 6,
#          'curb,': 1,
#          'followed': 23,
#          'pull': 1,
#          'bell.': 4,
#          'whistled.': 1,
#          'pair,': 1,
#          'sound,”': 1,
#          '“yes,”': 3,
#          'continued,': 6,
#          'glancing': 23,
#          'window.': 6,
#          'nice': 7,
#          'brougham': 3,
#          'pair': 11,
#          'beauties.': 1,
#          'hundred': 18,
#          'fifty': 8,
#          'guineas': 2,
#          'apiece.': 3,
#          'there’s': 9,
#          'money': 24,
#          'case,': 19,
#          'nothing': 87,
#          'else.”': 3,
#          'think': 133,
#          'better': 41,
#          'go,': 8,
#          'holmes.”': 5,
#          'bit,': 1,
#          'doctor.': 1,
#          'stay': 6,
#          'are.': 8,
#          'lost': 21,
#          'boswell.': 1,
#          'promises': 4,
#          'interesting.': 5,
#          'pity': 5,
#          'miss': 83,
#          'it.”': 35,
#          '“but': 85,
#          'client—”': 1,
#          '“never': 5,
#          'want': 25,
#          'help,': 6,
#          'comes.': 1,
#          'sit': 15,
#          'doctor,': 16,
#          'best': 26,
#          'attention.”': 1,
#          'slow': 3,
#          'step,': 1,
#          'stairs': 5,
#          'passage,': 11,
#          'paused': 3,
#          'immediately': 5,
#          'outside': 16,
#          'door.': 25,
#          'loud': 3,
#          'authoritative': 1,
#          'tap.': 1,
#          '“come': 4,
#          'in!”': 3,
#          'entered': 21,
#          'less': 38,
#          'feet': 18,
#          'inches': 1,
#          'height,': 3,
#          'limbs': 7,
#          'hercules.': 1,
#          'dress': 15,
#          'rich': 9,
#          'richness': 1,
#          'would,': 7,
#          'england,': 5,
#          'bad': 10,
#          'taste.': 1,
#          'bands': 2,
#          'astrakhan': 1,
#          'slashed': 1,
#          'sleeves': 2,
#          'fronts': 1,
#          'double-breasted': 1,
#          'coat,': 6,
#          'deep': 21,
#          'cloak': 3,
#          'thrown': 10,
#          'shoulders': 5,
#          'lined': 4,
#          'flame-coloured': 2,
#          'silk': 2,
#          'secured': 3,
#          'neck': 5,
#          'brooch': 1,
#          'consisted': 2,
#          'single': 18,
#          'flaming': 2,
#          'beryl.': 1,
#          'boots': 8,
#          'extended': 4,
#          'halfway': 2,
#          'calves,': 1,
#          'trimmed': 1,
#          'tops': 1,
#          'fur,': 1,
#          'completed': 4,
#          'impression': 15,
#          'barbaric': 1,
#          'opulence': 1,
#          'suggested': 9,
#          'appearance.': 4,
#          ...})

# %%
counter.get
# Out:
# <function Counter.get(key, default=None, /)>

# %%
# from the dictionary just get only the key: 
sorted_val = sorted(counter,key=counter.get,reverse=True)
print(sorted_val[:5])
print(len(sorted_val))
# Out:
# ['the', 'and', 'of', 'to', 'a']
# 14556

# %%
vocab = ["UNK","PAD"] + sorted_val[:10000]
len(vocab)
# Out:
# 10002

# %%
vocab_size = len(vocab)
word_to_idx = { word:idx for idx, word in enumerate(vocab)}
list(word_to_idx.items())[:5]
# Out:
# [('UNK', 0), ('PAD', 1), ('the', 2), ('and', 3), ('of', 4)]

# %%
idx_to_word = { idx:word for idx,word in enumerate(vocab)}
dict(list(idx_to_word.items())[:5])
# Out:
# {0: 'UNK', 1: 'PAD', 2: 'the', 3: 'and', 4: 'of'}

# %%
# we took only 10000, other token will be unkwon in final token:
unk_id = word_to_idx["UNK"]
unk_id
# Out:
# 0

# %%
final_idx = [word_to_idx.get(token,unk_id)  for token in final_token]
print(f"total size of final token: {len(final_idx)}")
final_idx[-10:-1]
# Out:
# total size of final token: 108061
# [0, 5, 67, 5980, 0, 5, 335, 77, 323]

# %%
# create sequence and next word:
seq_length=30
sequences = []
next_words = []
for i in range(len(final_idx)-seq_length):
    sequences.append(final_idx[i:(i+seq_length)])
    next_words.append(final_idx[i+seq_length])


# total number of sequence:
print(f"Total number of sequence : {len(sequences)}")
print(f"Total number of next_words : {len(next_words)}")
# Out:
# Total number of sequence : 108031
# Total number of next_words : 108031

# %% [markdown]
# <br>
# <br>
#
#
# # `#02: making the dataset:`
#
# <br>
# <br>

# %%
class CustomDataset(Dataset):
    def __init__(self,sequences,next_words):
        super().__init__()
        self.seq = torch.tensor(data=sequences,device=device,dtype=torch.long)
        self.nex = torch.tensor(data=next_words,device=device,dtype=torch.long)
        
    def __getitem__(self,idx):
        return self.seq[idx],self.nex[idx]
    
    def __len__(self):
        return len(self.seq)
    

dataset = CustomDataset(sequences,next_words)
dataloader = DataLoader(dataset=dataset,
                        batch_size=64,
                        shuffle=True)

# %%
class LSTMPredictor(nn.Module):
    def __init__(self,vocab_size,embedding_dim,hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings=vocab_size,embedding_dim=embedding_dim)
        #batch_first == True means, we have batch:
        self.lstm = nn.LSTM(input_size=embedding_dim,hidden_size=hidden_size,batch_first=True)
        self.fc = nn.Linear(hidden_size,vocab_size)
        
    def forward(self,x):
        embed = self.embedding(x)
        # 3 thing in output in  LSTM cell
        lstm_out, (hidden,_) = self.lstm(embed)
        out = self.fc(torch.squeeze(hidden,dim=0))
        return out 
    
    
    
model = LSTMPredictor(vocab_size=vocab_size,embedding_dim=100,hidden_size=512,)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(),lr=0.01)

# %%
# tranning loop:
epochs = 100

for epoch in range(epochs):
    total_loss = 0
    for input,next_word in dataloader:
        input = input.to(device)
        next_word = next_word.to(device)
        
        #forward pass
        out = model(input)
        
        #calculate loss:
        loss = criterion(out,next_word)
        
        #gradient accumulation:
        optimizer.zero_grad()
        
        #backward pass 
        loss.backward()

        #update parameters
        optimizer.step()
        
        total_loss += loss.item()
    print(f"epoch: {epoch+1}  loss: {total_loss/len(dataloader)}")
# Out:
# epoch: 1  loss: 6.236257062139105
# epoch: 2  loss: 5.225727141185959
# epoch: 3  loss: 4.579768206412194
# epoch: 4  loss: 4.1105269084892
# epoch: 5  loss: 3.7528984755701362
# epoch: 6  loss: 3.488329418603843
# epoch: 7  loss: 3.2931196915594887
# epoch: 8  loss: 3.1347986291652608
# epoch: 9  loss: 3.034739357035307
# epoch: 10  loss: 2.939432405323779
# epoch: 11  loss: 2.852806206704316
# epoch: 12  loss: 2.794746967288555
# epoch: 13  loss: 2.7376766732377464
# epoch: 14  loss: 2.7048472960554593
# epoch: 15  loss: 2.664928324555899
# epoch: 16  loss: 2.6310500129704226
# epoch: 17  loss: 2.613844110643694
# epoch: 18  loss: 2.5926960302755164
# epoch: 19  loss: 2.559420862680928
# epoch: 20  loss: 2.5230712576358805
# epoch: 21  loss: 2.5091636327064433
# epoch: 22  loss: 2.5215754332418125
# epoch: 23  loss: 2.4853225355323456
# epoch: 24  loss: 2.465808705201646
# epoch: 25  loss: 2.4647261320273457
# epoch: 26  loss: 2.443318507965142
# epoch: 27  loss: 2.420736211806677
# epoch: 28  loss: 2.411819362174278
# epoch: 29  loss: 2.418257689730251
# epoch: 30  loss: 2.4218886085737372
# epoch: 31  loss: 2.4085933158606716
# epoch: 32  loss: 2.3830562700733755
# epoch: 33  loss: 2.367056557211266
# epoch: 34  loss: 2.3629313871193838
# epoch: 35  loss: 2.3441708290605185
# epoch: 36  loss: 2.326374659959174
# epoch: 37  loss: 2.294911079144026
# epoch: 38  loss: 2.3085892041571334
# epoch: 39  loss: 2.2970429860867596
# epoch: 40  loss: 2.2923696814413885
# epoch: 41  loss: 2.287087705392408
# epoch: 42  loss: 2.2585246020583747
# epoch: 43  loss: 2.2666840941702584
# epoch: 44  loss: 2.255610544958386
# epoch: 45  loss: 2.251329421714584
# epoch: 46  loss: 2.2708462862324374
# epoch: 47  loss: 2.2683158858692476
# epoch: 48  loss: 2.2454533809310453
# epoch: 49  loss: 2.2404833830787108
# epoch: 50  loss: 2.221942503658516
# epoch: 51  loss: 2.2150842788236402
# epoch: 52  loss: 2.2105373910394324
# epoch: 53  loss: 2.1937384214163957
# epoch: 54  loss: 2.1954332666374494
# epoch: 55  loss: 2.189269767694564
# epoch: 56  loss: 2.172882913413206
# epoch: 57  loss: 2.1677129115397333
# epoch: 58  loss: 2.1781667062032843
# epoch: 59  loss: 2.182965450589126
# epoch: 60  loss: 2.191631982959277
# epoch: 61  loss: 2.162874276745376
# epoch: 62  loss: 2.1790693257516027
# epoch: 63  loss: 2.2276021862905737
# epoch: 64  loss: 2.1798405910696466
# epoch: 65  loss: 2.160370190420422
# epoch: 66  loss: 2.1445760222690367
# epoch: 67  loss: 2.156955961579395
# epoch: 68  loss: 2.1383171207955662
# epoch: 69  loss: 2.103928676572456
# epoch: 70  loss: 2.127954333173155
# epoch: 71  loss: 2.101540671846878
# epoch: 72  loss: 2.086020091839876
# epoch: 73  loss: 2.103742929360878
# epoch: 74  loss: 2.0958712003524833
# epoch: 75  loss: 2.080950765671888
# epoch: 76  loss: 2.081566515409551
# epoch: 77  loss: 2.0745150113204645
# epoch: 78  loss: 2.0572113326234276
# epoch: 79  loss: 2.053628931042707
# epoch: 80  loss: 2.0491866728564574
# epoch: 81  loss: 2.0299817197272
# epoch: 82  loss: 2.037107500702284
# epoch: 83  loss: 2.0386740222785145
# epoch: 84  loss: 2.0110604602013717
# epoch: 85  loss: 2.0051410031191548
# epoch: 86  loss: 2.0209207387897075
# epoch: 87  loss: 1.9974455495157513
# epoch: 88  loss: 2.0099234216939217
# epoch: 89  loss: 2.024704725750815
# epoch: 90  loss: 1.9991428465074836
# epoch: 91  loss: 1.9891724008095772
# epoch: 92  loss: 1.998703386581622
# epoch: 93  loss: 1.9745214955077917
# epoch: 94  loss: 1.9836485190272897
# epoch: 95  loss: 1.972457742733413
# epoch: 96  loss: 1.9569991501445454
# epoch: 97  loss: 1.9617514040727186
# epoch: 98  loss: 1.970815180390367
# epoch: 99  loss: 1.963362230226327
# epoch: 100  loss: 1.9907172151368941

# %%
# prediction:
def prediction(model,sentences,seq_length,word_to_idx,idx_to_word):
    model.eval()
    with torch.no_grad():
        token = sentences.lower().split()
        generated = token.copy()
        
        for _ in range(seq_length):
            # 1. seq_length
            if len(token)>=seq_length:
                current_tokens = generated[-seq_length:]
            else:
                current_tokens = generated 
                
            # 2. get unk,pad idx
            unk_idx = word_to_idx["UNK"]
            pad_idx = word_to_idx["PAD"]
    
            # 3. get idx value
            indices = [word_to_idx.get(tok,unk_idx) for tok in current_tokens]
    
            # 4. fit with seq_length
            if len(indices)<seq_length:
                indices += [pad_idx]*(seq_length-len(indices)) 
    
            # 5. convert into tensor:
            input_tensor = torch.tensor([indices], dtype=torch.long).to(device)
            output = model(input_tensor)
            probabilities = torch.softmax(output, dim=1)
            predicted_idx = torch.argmax(probabilities,dim=1).item()
            predicted_words = idx_to_word.get(predicted_idx,"<UNKNOWN>")
            generated.append(predicted_words)
        return " ".join(generated)

test_sentences = [
    "to sherlock holmes she is always",
    "i have never seen",
    "the quick brown fox",
    "my dear watson",
    "it was a dark and"]

for sentence in test_sentences:
    result = prediction(model,sentence,seq_length,word_to_idx,idx_to_word)
    print(f"sentence: {sentence}  prediction: {result}")
    print()
# Out:
# sentence: to sherlock holmes she is always  prediction: to sherlock holmes she is always conversation others it.” bundle surprise equally are, chair. really lie got morning, nine breath, me. set beneath. suddenly miserable bowed shortly round fallen appointment this file lady could not mine
#
# sentence: i have never seen  prediction: i have never seen myself, locked, suddenly shut sitting-room attention. now press on, suddenly conduct resolute if returned purpose. shortly gained formerly, overtook lips on, doubt interest stair. chair. chair. the project copying, hand
#
# sentence: the quick brown fox  prediction: the quick brown fox announced letter completed explanation suddenly think.” explanation fifty clutched belonging since upon. UNK good slammed remain massive approaching sending wander wander occasional “we keen limbs suits you,” said he, rising
#
# sentence: my dear watson  prediction: my dear watson effort UNK sitting-room part hypothesis listen story. rather exact wants, holmes. give leaving your explanation quite aside opposite head, “‘dear reference home, overtook very thirty, fifty feature. he has me
#
# sentence: it was a dark and  prediction: it was a dark and resolute he her, resolute he paused interest each myself, now.” conversation hand stone cast to-night.” that?” head, head, eight words reached sitting-room ended you interested the UNK road, there burst
